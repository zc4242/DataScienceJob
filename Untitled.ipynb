# %%
ls
# Out:
# Job Class Desc external id.xlsx  Untitled.ipynb
# Job Description Scraping.ipynb

# %%
import pandas as pd

# %%
a=pd.read_excel('Job Class Desc external id.xlsx')

# %%
for idx,row in a.iterrows():
    print("jobExternalId.put('"+row['LAWSON Job Class Code']+"','"+row['B']+"');")
# Out:
# jobExternalId.put('MP','LABOPS:MGRPLANNING');
# jobExternalId.put('PLN','LABOPS:PLANNER');
# jobExternalId.put('MLO','LABOPS:MGRLABOPS');
# jobExternalId.put('DDS','LABANALYSIS:DIRSCI');
# jobExternalId.put('DBS','LABANALYSIS:DIRBIOANLYTCLSVCS');
# jobExternalId.put('BIS','LABANALYSIS:DIRBIOANLYTCLSCI');
# jobExternalId.put('PML','LABANALYSIS:PROJMGRLAB');
# jobExternalId.put('MCL','LABANALYSIS:MGRCLINLAB');
# jobExternalId.put('PDL','LABANALYSIS:PROJDIRLAB');
# jobExternalId.put('BTL','LABANALYSIS:BIOANLYTCLTEAMLD');
# jobExternalId.put('PBS','LABANALYSIS:SCIENTIST');
# jobExternalId.put('PLA','LABANALYSIS:LABANLYST');
# jobExternalId.put('LAS','LABANALYSIS:LABASSOC');
# jobExternalId.put('P28','PHARMACOKINETICS:PHARMACOKINETICIST');
# jobExternalId.put('A31','SAMPLEPROCESSING:SMPLRECEIPTASSOC');
# jobExternalId.put('TLS','SAMPLEPROCESSING:TEAMLDSMPLPROCLAB');
# jobExternalId.put('A2','ADMINSUPPT:ADMINASSOC');
# jobExternalId.put('M64','ADMINSUPPT:MGRADMINSVCS');
# ...
